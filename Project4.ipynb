# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

columns = ['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
    'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
    'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
    'stalk-surface-below-ring', 'stalk-color-above-ring',
    'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
    'ring-type', 'spore-print-color', 'population', 'habitat']

df = pd.read_csv('agaricus-lepiota.data', names=columns)

df = df[['class', 'odor', 'population']]
df.columns = ['edible_or_poisonous', 'odor', 'population']
df.head()
# Out:
#   edible_or_poisonous odor population
# 0                   p    p          s
# 1                   e    a          n
# 2                   e    l          n
# 3                   p    p          s
# 4                   e    n          a

# %%
df['edible_or_poisonous'] = df['edible_or_poisonous'].replace({'e': 0, 'p': 1})
df.head()
# Out:
# <ipython-input-21-b055b58fc7ac>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['edible_or_poisonous'] = df['edible_or_poisonous'].replace({'e': 0, 'p': 1})
#    edible_or_poisonous odor population
# 0                    1    p          s
# 1                    0    a          n
# 2                    0    l          n
# 3                    1    p          s
# 4                    0    n          a

# %%
predictors = ['odor', 'population']
y = df['edible_or_poisonous']

for col in predictors:
    X = pd.get_dummies(df[col], drop_first=True)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    model = LogisticRegression(max_iter=300)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy using '{col}' as predictor: {accuracy:.4f}")
# Out:
# Accuracy using 'odor' as predictor: 0.9840
# Accuracy using 'population' as predictor: 0.7240

# %% [markdown]
# ### Conclusions
#
# The odor predictor did a much better job of predicting whether a mushroom is poisonous compared to population. This shows that odor is a really strong feature for this task. I suggest trying to combine multiple predictors, like odor and gill-color, in future work to see if that improves the model’s accuracy even more.
